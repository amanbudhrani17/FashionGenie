# %%
# This file contains the trend analysis based on region which will be used in genAI for both chatbot and diffusion model.

# %%
# !pip3 install pytrends
# Out:
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
trending_US = pytrends.trending_searches(pn='india') # trending searches in real time for United States

# %%
trending_US.head()
# Out:
#                      0
# 0             Man City
# 1                  CPL
# 2          Inter Miami
# 3  Man City vs Sevilla
# 4       Parsi New Year

# %%
rtst_US=pytrends.realtime_trending_searches(pn='IN') # realtime search trends for United States

# %%
print(rtst_US)
# Out:
#                                                 title  \
# 0   Manchester City F.C., Sevilla FC, UEFA Super C...
# 1   West Ham United F.C., Lucas Paquetá, Mancheste...
# 2   Enzo Amore, Bubba Ray Dudley, WWE Superstars, ...
# 3   UEFA Europa League, Liverpool F.C., Odds, 2023...
# 4             Hulk Hogan, WWE, Professional wrestling
# ..                                                ...
# 75      Sustainability, Hospitality industry, Finance
# 76                      Construction, Heavy equipment
# 77  New Zealand, Agribusiness, Greenhouse gas, Cli...
# 78  Argentina, Argentine Peso, United States Dolla...
# 79  Formula 1, Honda Motor Company, Aston Martin A...
#
#                                           entityNames
# 0   [Manchester City F.C., Sevilla FC, UEFA Super ...
# 1   [West Ham United F.C., Lucas Paquetá, Manchest...
# 2   [Enzo Amore, Bubba Ray Dudley, WWE Superstars,...
# 3   [UEFA Europa League, Liverpool F.C., Odds, 202...
# ...

# %%
pytrends.trending_searches(pn='india')
# Out:
#                               0
# 0                      Man City
# 1                           CPL
# 2                   Inter Miami
# 3           Man City vs Sevilla
# 4                Parsi New Year
# 5              SBFC share price
# 6     Mohun Bagan vs Machhindra
# 7         IBPS Clerk Admit Card
# 8                   Darren Kent
# 9                      MS Dhoni
# 10                Saif Ali Khan
# 11         Australia vs England
# 12                  Rishi sunak
# 13               Bittu Bajrangi
# 14  Cochin Shipyard Share Price
# 15        Himachal Pradesh news
# 16                 Sharad Pawar
# 17                  Morari Bapu
# 18                 Elvish Yadav
# 19                   IND vs IRE

# %%
pytrends.suggestions('Festivals')
# Out:
# [{'mid': '/g/11mh_xk6c1', 'title': 'Ik ga leven', 'type': 'Book by Lale Gül'},
#  {'mid': '/g/11fqq6kk9g',
#   'title': "Gastro Obscura: A Food Adventurer's Guide",
#   'type': 'Book by Cecily Wong and Dylan Thuras'},
#  {'mid': '/g/11h1s84jk6', 'title': 'Titania McGrath', 'type': 'Writer'},
#  {'mid': '/m/010jkmkf',
#   'title': 'The Pigeon Needs a Bath!',
#   'type': 'Book by Mo Willems'},
#  {'mid': '/g/113w1l351', 'title': 'Trisha Das', 'type': 'Writer'}]

# %%
# Out:
#                               0
# 0                      Man City
# 1                           CPL
# 2                   Inter Miami
# 3           Man City vs Sevilla
# 4                Parsi New Year
# 5              SBFC share price
# 6     Mohun Bagan vs Machhindra
# 7         IBPS Clerk Admit Card
# 8                   Darren Kent
# 9                      MS Dhoni
# 10                Saif Ali Khan
# 11         Australia vs England
# 12                  Rishi sunak
# 13               Bittu Bajrangi
# 14  Cochin Shipyard Share Price
# 15        Himachal Pradesh news
# 16                 Sharad Pawar
# 17                  Morari Bapu
# 18                 Elvish Yadav
# 19                   IND vs IRE
